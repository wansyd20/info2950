# %%
import pandas as pd

# %% [markdown]
# # Cleaning and Loading Amazon Review Datasets
# We are using the Electronics category to demonstrate how we loaded and narrowed down the review dataset process. We performed the same processes to three other Amazon review categories (Beauty, Office Products, Apparel) in separate JupyterNotebook files. We loaded those here and merged all the cleaned datasets into one comprehensive dataset, which we have provided in CMS.

# %%
electronics = pd.read_csv('/Users/michellehui/info2950_project/amazon_reviews_us_Electronics_v1_00.tsv', sep = '\t', error_bad_lines=False)
# Out:
# b'Skipping line 9076: expected 15 fields, saw 22\nSkipping line 19256: expected 15 fields, saw 22\nSkipping line 24313: expected 15 fields, saw 22\nSkipping line 47211: expected 15 fields, saw 22\nSkipping line 54295: expected 15 fields, saw 22\nSkipping line 56641: expected 15 fields, saw 22\nSkipping line 63067: expected 15 fields, saw 22\n'
# b'Skipping line 93796: expected 15 fields, saw 22\n'
# b'Skipping line 132806: expected 15 fields, saw 22\nSkipping line 164631: expected 15 fields, saw 22\nSkipping line 167019: expected 15 fields, saw 22\nSkipping line 167212: expected 15 fields, saw 22\n'
# b'Skipping line 198103: expected 15 fields, saw 22\nSkipping line 199191: expected 15 fields, saw 22\nSkipping line 202841: expected 15 fields, saw 22\nSkipping line 218228: expected 15 fields, saw 22\nSkipping line 235900: expected 15 fields, saw 22\n'
# ...

# %%
# keeping reviews written in 2015
electronics['review_date'] = pd.to_datetime(electronics['review_date'])
electronics = electronics.loc[electronics['review_date'].dt.year == 2015]

# %%
# dropping marketplace column
# electronics = electronics.drop(columns= ['marketplace'], axis=1)
electronics.head(-5)
# Out:
#         customer_id       review_id  product_id  product_parent  \
# 497780     33503582   RHF5K0OJT2AIT  B00B1JLN28       529306528
# 668728     33690533  R19L1JJA6MQREE  B002UKSZUU       636125853
# 48964      14680652   RW9YLEATLKMUX  B00GAJ2OK4       453387157
# 49189      33460236   R4NF0PYH2OQCP  B009K4J8RS       725694355
# 323148     26625194  R16KY02QCCEVIE  B004QOA93E       523816887
# ...             ...             ...         ...             ...
# 655523     32783696   RJZ415ACIDGGI  B00HY4PICU       493178902
# 778537     26707138  R11KMNSYV5XTMB  B00EWCUK1Q       779758615
# 401691     42999426  R3LF3D297OQHNM  B00OHDONOA       118146110
# 363858     50888629  R39FV0RIYX60IA  B0055YB7IA       284992326
# 366036     42096690  R1OPOV8KT7FFQ8  B005N8W1H4       792640986
#
#                                             product_title product_category  \
# 497780  Valley Enterprises® 2.1mm x 5.5mm DC Power Cou...      Electronics
# ...

# %%
# randomly narrowing down 800,000 observations to 10,000
electronics = electronics.sample(n=10000)
electronics.reset_index()
# Out:
#        index  customer_id       review_id  product_id  product_parent  \
# 0     220982     20629638  R28COXZFGZBCD7  B00TF9UDZ4       517979103
# 1     229461     22433142  R3JWQ7N8ZTBE87  B00M4LBO12       197982615
# 2     358648     46722229   RA1FWXIPF7Y3V  B00OHHG768       720920423
# 3      91682     45124887  R3NERI9H0KG3MY  B005YHC4LW       388719783
# 4     226242     32907802  R1P6JH0BI5A0BW  B00VW7U8X4       126472652
# ...      ...          ...             ...         ...             ...
# 9995  253690      3169320   RGBKW78AOVOLU  B0012S4APK       845709830
# 9996  770150     42041779  R38F428AF50AH4  B002MAPT7U       808084969
# 9997  649316     23656471   RICGERXXQBCT1  B007136EBI       957426788
# 9998  219224     32301879   RWJLZGH7MD21Y  B007LG453Y       774135424
# 9999  502288     31045820  R1BCV1IGMS2L4W  B003L14XTO       792985538
#
#                                           product_title product_category  \
# ...

# %%
# downloading cleaned csv file
electronics.to_csv('amazonreviews_electronics.csv',index=False)
